# %% [markdown]
# # 🏎️ F1 Dashboard
#
# ### 🥉 Bronze Layer
#
# **Owner** 👨‍💻: Matheus Rodrigues </br>
# **Status** 🚦: In Progress </br>
# **Description** 📖: A dashboard to analyze Formula 1 data, consuming fastf1 API. <br/>
# **Last Update** 📅 : 2026-02-28 <br/>
# ___

# %%
# Install dependencies
# %pip install -r ../requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: '../requirements.txt'
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import libraries
from pyspark.sql import SparkSession
from matplotlib import pyplot as plt
from pathlib import Path
import pandas as pd
import fastf1

# %%
# Define variables
years = [2023, 2024, 2025]
circuits = ['Monza', 'Silverstone', 'Spa-Francorchamps', 'Suzuka', 'Interlagos']
sessions = ['FP1', 'FP2', 'FP3', 'Q', 'Race']

# %%
# Create a dataframe of circuits and their locations
circuits_df = []
for year in years:
    schedule = fastf1.get_event_schedule(year)
    df_schedule = pd.DataFrame(schedule)

    circuits_df.append(df_schedule)


final_circuits_df = pd.concat(circuits_df, ignore_index=True)
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (48.34 MB) C:\Users\mathe\AppData\Local\Temp\fastf1

# %%
# Teste
display(final_circuits_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 3
#       1 # Create a dataframe of
# ----> 3 session = fastf1.core.Session("French Grand Prix", "Q")
#       4 session.load()
#       5 session.results
#
# File c:\projects\analytics-monitor-f1\.venv\Lib\site-packages\fastf1\core.py:1174, in Session.__init__(self, event, session_name, f1_api_support)
#    1171 self.f1_api_support = f1_api_support
#    1172 """bool: The official F1 API supports this event and lap timing
#    1173 data and telemetry data are available."""
# -> 1174 self.date = self.event.get_session_date(session_name, utc=True)
#    1175 """pandas.Datetime: Date at which this session took place."""
#    1177 try:
#
# AttributeError: 'str' object has no attribute 'get_session_date'
